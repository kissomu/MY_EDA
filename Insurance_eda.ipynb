# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv('/content/insurance (1).csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ## **Perform EDA on Insurance Data and identify the variables what are responsible for affecting the variable "charges"**

# %%
df.nunique()
# Out:
# age           47
# sex            2
# bmi          548
# children       6
# smoker         2
# region         4
# charges     1337
# dtype: int64

# %% [markdown]
# # Here we can see number of male and female children region wise.

# %%
df.groupby(by = ["sex","region"])["children"].sum().reset_index()
# Out:
#       sex     region  children
# 0  female  northeast       162
# 1  female  northwest       183
# 2  female  southeast       184
# 3  female  southwest       182
# 4    male  northeast       177
# 5    male  northwest       190
# 6    male  southeast       198
# 7    male  southwest       189

# %%
sns.heatmap(df.corr(),annot=True,cmap="Blues" ).set(title='Corelation')
# Out:
# [Text(0.5, 1.0, 'Corelation')]

# %% [markdown]
# # heatmap showing correlation, where highest correlation is 1(blue) and lowest  0.2(white)

# %%
sns.barplot(x = 'smoker',
            y = 'charges',
            hue = 'region',
            data = df).set(title='Reason of affecting charges')
# Out:
# [Text(0.5, 1.0, 'Reason of affecting charges')]

# %% [markdown]
# # conclusion - 1.According to this barplot we can see the reason of increasing charges is smokers.
# # 2.Also area wise smokers and there charges
# # 3.the one who smokes there charges are high as compare to the one who not smoke.

# %%
df.head(2)
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523

# %%
sns.countplot(df['smoker']).set(title='smokers')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# [Text(0.5, 1.0, 'smokers')]

# %% [markdown]
# # By this plot we can see smoker are less then non smokers

# %%
df.head(2)
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523

# %%
sns.pairplot(df,hue='smoker')

# %% [markdown]
# in this pair plot we can compare smokers with all the variable and here we can see following conclustion-
# # 1.Charges are high when there is smokers.
# # 2.In the bmi 20 to 40 theere is most number of smokers
# # 3.No children is smoker
# # 4.Most of the smokers are  between 20 to 70 age .

# %%
sns.scatterplot(df['age'], df['charges'], hue = df['smoker']).set(title='scatterplot')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# [Text(0.5, 1.0, 'scatterplot')]

# %% [markdown]
# # conclusion - in this scatterplot we can also see the same conculsion

# %%
df.head(2)
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523

# %%
sns.violinplot(x="smoker",y="charges", data=df, size=8).set(title='Violinplot')
# Out:
# [Text(0.5, 1.0, 'Violinplot')]
